# %%
from pandas import DataFrame, Series

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd; import numpy as np

# %%
records = pd.read_excel('line_dance.xls', encoding='utf-8')

# %%
records.describe()
# Out:
#         年龄区间   职业  参与年限      单次时长   每周频次        了解途径     参与途径
# count    160  160   160       160    160         160      160
# unique     5    5     4         5      6           4        4
# top     59>岁   职员  小于1年  60--90分钟  每周4-5  亲身参与培训, 比赛  参与专门的培训
# freq      40   46    46        45     31          63       56

# %%
records.index
# Out:
# RangeIndex(start=0, stop=160, step=1)

# %%
records.values
# Out:
# array([['15-29岁', '学生', '小于1年', ..., '每周1次', '亲身参与培训, 比赛', '参与各级比赛'],
#        ['30-44岁', '其他', '小于1年', ..., '每天多次', '亲身参与培训, 比赛', '群众组织'],
#        ['30-44岁', '自由职业', '大于5年', ..., '每周4-5', '媒体(互联网, 手机)', '视频学习'],
#        ...,
#        ['<15岁', '学生', '3-5年', ..., '其他', '朋友介绍', '参与各级比赛'],
#        ['<15岁', '学生', '1-3年', ..., '每周4-5', '朋友介绍', '参与各级比赛'],
#        ['<15岁', '其他', '1-3年', ..., '每周1次', '朋友介绍', '参与专门的培训']],
#       dtype=object)

# %%
records.columns
# Out:
# Index(['年龄区间', '职业', '参与年限', '单次时长', '每周频次', '了解途径', '参与途径'], dtype='object')

# %%
records.describe()
# Out:
#         年龄区间   职业  参与年限      单次时长   每周频次        了解途径     参与途径
# count    160  160   160       160    160         160      160
# unique     5    5     4         5      6           4        4
# top     59>岁   职员  小于1年  60--90分钟  每周4-5  亲身参与培训, 比赛  参与专门的培训
# freq      40   46    46        45     31          63       56

# %%
records.T
# Out:
#              0           1            2            3           4    \
# 年龄区间      15-29岁      30-44岁       30-44岁       15-29岁      30-44岁
# 职业            学生          其他         自由职业           职员          其他
# 参与年限        小于1年        小于1年         大于5年         3-5年        大于5年
# 单次时长    45--60分钟     大于120分钟     60--90分钟      大于120分钟    60--90分钟
# 每周频次        每周1次        每天多次        每周4-5         每天多次          其他
# 了解途径  亲身参与培训, 比赛  亲身参与培训, 比赛  媒体(互联网, 手机)  媒体(互联网, 手机)  亲身参与培训, 比赛
# 参与途径      参与各级比赛        群众组织         视频学习       参与各级比赛     参与专门的培训
#
#              5       6            7      8            9     ...     \
# 年龄区间      30-44岁  45-59岁         <15岁   <15岁       30-44岁   ...
# 职业            职员    自由职业           其他     学生           职员   ...
# 参与年限        小于1年    小于1年         大于5年   3-5年         小于1年   ...
# 单次时长      小于45分钟  小于45分钟       小于45分钟  120分钟        120分钟   ...
# 每周频次       每周4-5    每周1次        每周4-5   每周1次        每周4-5   ...
# ...

# %%
records.sort_index(axis=1, ascending=False)
# Out:
#        职业   每周频次    年龄区间     参与途径  参与年限      单次时长         了解途径
# 0      学生   每周1次  15-29岁   参与各级比赛  小于1年  45--60分钟   亲身参与培训, 比赛
# 1      其他   每天多次  30-44岁     群众组织  小于1年   大于120分钟   亲身参与培训, 比赛
# 2    自由职业  每周4-5  30-44岁     视频学习  大于5年  60--90分钟  媒体(互联网, 手机)
# 3      职员   每天多次  15-29岁   参与各级比赛  3-5年   大于120分钟  媒体(互联网, 手机)
# 4      其他     其他  30-44岁  参与专门的培训  大于5年  60--90分钟   亲身参与培训, 比赛
# 5      职员  每周4-5  30-44岁   参与各级比赛  小于1年    小于45分钟   亲身参与培训, 比赛
# 6    自由职业   每周1次  45-59岁     群众组织  小于1年    小于45分钟         朋友介绍
# 7      其他  每周4-5    <15岁     视频学习  大于5年    小于45分钟  媒体(互联网, 手机)
# 8      学生   每周1次    <15岁     视频学习  3-5年     120分钟        书刊,杂志
# 9      职员  每周4-5  30-44岁     视频学习  小于1年     120分钟  媒体(互联网, 手机)
# 10     职员   每周1次    <15岁     群众组织  小于1年  45--60分钟   亲身参与培训, 比赛
# 11     职员  每周4-5    <15岁  参与专门的培训  3-5年   大于120分钟         朋友介绍
# 12     职员  每周4-5    <15岁  参与专门的培训  3-5年    小于45分钟  媒体(互联网, 手机)
# 13   自由职业   每天1次  15-29岁     视频学习  大于5年   大于120分钟   亲身参与培训, 比赛
# ...

# %%
records.sort_values(by='每周频次')
# Out:
#        年龄区间    职业  参与年限      单次时长  每周频次         了解途径     参与途径
# 48     <15岁    职员  3-5年     120分钟    其他   亲身参与培训, 比赛  参与专门的培训
# 32     59>岁    职员  3-5年     120分钟    其他   亲身参与培训, 比赛     视频学习
# 95   30-44岁    职员  小于1年  45--60分钟    其他   亲身参与培训, 比赛  参与专门的培训
# 29   30-44岁    学生  大于5年    小于45分钟    其他  媒体(互联网, 手机)     群众组织
# 28     59>岁  自由职业  1-3年   大于120分钟    其他         朋友介绍     视频学习
# 100    59>岁  自由职业  大于5年  45--60分钟    其他   亲身参与培训, 比赛   参与各级比赛
# 101  45-59岁    学生  1-3年   大于120分钟    其他         朋友介绍  参与专门的培训
# 50   15-29岁    无业  小于1年     120分钟    其他  媒体(互联网, 手机)   参与各级比赛
# 23     59>岁    学生  小于1年  45--60分钟    其他   亲身参与培训, 比赛  参与专门的培训
# 22     <15岁    职员  小于1年   大于120分钟    其他         朋友介绍     视频学习
# 73     59>岁    其他  大于5年    小于45分钟    其他         朋友介绍   参与各级比赛
# 19   30-44岁    无业  小于1年   大于120分钟    其他  媒体(互联网, 手机)     视频学习
# 108    59>岁    学生  1-3年   大于120分钟    其他   亲身参与培训, 比赛   参与各级比赛
# 82   15-29岁    学生  大于5年   大于120分钟    其他   亲身参与培训, 比赛     视频学习
# ...

# %%
records['职业']
# Out:
# 0        学生
# 1        其他
# 2      自由职业
# 3        职员
# 4        其他
# 5        职员
# 6      自由职业
# 7        其他
# 8        学生
# 9        职员
# 10       职员
# 11       职员
# 12       职员
# 13     自由职业
# 14       其他
# 15       学生
# 16       无业
# 17       无业
# 18       职员
# 19       无业
# 20       学生
# 21       其他
# 22       职员
# 23       学生
# 24       学生
# 25       职员
# 26       其他
# 27     自由职业
# 28     自由职业
# 29       学生
#        ...
# 130      学生
# 131      学生
# 132      学生
# 133      学生
# 134      学生
# 135      职员
# 136      职员
# 137      职员
# 138      学生
# 139      学生
# 140      职员
# 141      学生
# 142      职员
# 143      其他
# 144      职员
# 145      其他
# 146      无业
# 147      无业
# 148      无业
# 149      其他
# 150    自由职业
# 151      无业
# 152      学生
# 153      其他
# 154    自由职业
# 155      职员
# 156      职员
# 157      学生
# 158      学生
# 159      其他
# Name: 职业, Length: 160, dtype: object

# %%
records['职业'].describe()
# Out:
# count     160
# unique      5
# top        职员
# freq       46
# Name: 职业, dtype: object

# %%
records[0:3]
# Out:
#      年龄区间    职业  参与年限      单次时长   每周频次         了解途径    参与途径
# 0  15-29岁    学生  小于1年  45--60分钟   每周1次   亲身参与培训, 比赛  参与各级比赛
# 1  30-44岁    其他  小于1年   大于120分钟   每天多次   亲身参与培训, 比赛    群众组织
# 2  30-44岁  自由职业  大于5年  60--90分钟  每周4-5  媒体(互联网, 手机)    视频学习

# %%
records[100: 160]
# Out:
#        年龄区间    职业  参与年限      单次时长   每周频次         了解途径     参与途径
# 100    59>岁  自由职业  大于5年  45--60分钟     其他   亲身参与培训, 比赛   参与各级比赛
# 101  45-59岁    学生  1-3年   大于120分钟     其他         朋友介绍  参与专门的培训
# 102  30-44岁    职员  3-5年  45--60分钟   每周1次         朋友介绍   参与各级比赛
# 103  30-44岁    学生  小于1年  60--90分钟   每天1次         朋友介绍   参与各级比赛
# 104  30-44岁    学生  1-3年  60--90分钟   每周1次   亲身参与培训, 比赛  参与专门的培训
# 105  30-44岁    职员  小于1年  60--90分钟   每天1次         朋友介绍  参与专门的培训
# 106  30-44岁    学生  1-3年   大于120分钟   每周1次   亲身参与培训, 比赛   参与各级比赛
# 107  45-59岁    职员  1-3年  60--90分钟   每天1次   亲身参与培训, 比赛   参与各级比赛
# 108    59>岁    学生  1-3年   大于120分钟     其他   亲身参与培训, 比赛   参与各级比赛
# 109  45-59岁    职员  大于5年  45--60分钟   每天多次         朋友介绍   参与各级比赛
# 110  30-44岁    职员  1-3年  60--90分钟   每天多次         朋友介绍  参与专门的培训
# 111    59>岁    职员  小于1年  60--90分钟  每周2-3         朋友介绍  参与专门的培训
# 112  45-59岁    职员  1-3年   大于120分钟  每周2-3   亲身参与培训, 比赛  参与专门的培训
# 113  45-59岁    学生  1-3年  45--60分钟     其他         朋友介绍  参与专门的培训
# ...

# %%
records.loc[:,['年龄区间', '职业']]
# Out:
#        年龄区间    职业
# 0    15-29岁    学生
# 1    30-44岁    其他
# 2    30-44岁  自由职业
# 3    15-29岁    职员
# 4    30-44岁    其他
# 5    30-44岁    职员
# 6    45-59岁  自由职业
# 7      <15岁    其他
# 8      <15岁    学生
# 9    30-44岁    职员
# 10     <15岁    职员
# 11     <15岁    职员
# 12     <15岁    职员
# 13   15-29岁  自由职业
# 14   15-29岁    其他
# 15   45-59岁    学生
# 16     59>岁    无业
# 17   45-59岁    无业
# 18   45-59岁    职员
# 19   30-44岁    无业
# 20     <15岁    学生
# 21     59>岁    其他
# 22     <15岁    职员
# 23     59>岁    学生
# 24   15-29岁    学生
# 25     <15岁    职员
# 26     <15岁    其他
# 27   15-29岁  自由职业
# 28     59>岁  自由职业
# 29   30-44岁    学生
# ..      ...   ...
# 130    59>岁    学生
# 131  45-59岁    学生
# 132    59>岁    学生
# 133    59>岁    学生
# 134  45-59岁    学生
# 135    59>岁    职员
# 136    59>岁    职员
# 137  45-59岁    职员
# 138  45-59岁    学生
# 139  45-59岁    学生
# 140  45-59岁    职员
# 141    59>岁    学生
# 142    59>岁    职员
# 143    59>岁    其他
# 144  30-44岁    职员
# 145  30-44岁    其他
# 146    59>岁    无业
# 147    59>岁    无业
# ...

# %%
records.loc[100: 160, ['年龄区间', '职业']]
# Out:
#        年龄区间    职业
# 100    59>岁  自由职业
# 101  45-59岁    学生
# 102  30-44岁    职员
# 103  30-44岁    学生
# 104  30-44岁    学生
# 105  30-44岁    职员
# 106  30-44岁    学生
# 107  45-59岁    职员
# 108    59>岁    学生
# 109  45-59岁    职员
# 110  30-44岁    职员
# 111    59>岁    职员
# 112  45-59岁    职员
# 113  45-59岁    学生
# 114    59>岁    职员
# 115    59>岁    职员
# 116  30-44岁    学生
# 117    59>岁    职员
# 118    59>岁    学生
# 119    59>岁    学生
# 120  30-44岁    职员
# 121    59>岁    学生
# 122  45-59岁    职员
# 123  45-59岁    职员
# 124  30-44岁    学生
# 125  45-59岁    职员
# 126  45-59岁    学生
# 127    59>岁    学生
# 128  45-59岁    职员
# 129    59>岁    职员
# 130    59>岁    学生
# 131  45-59岁    学生
# 132    59>岁    学生
# 133    59>岁    学生
# 134  45-59岁    学生
# 135    59>岁    职员
# 136    59>岁    职员
# 137  45-59岁    职员
# 138  45-59岁    学生
# 139  45-59岁    学生
# 140  45-59岁    职员
# 141    59>岁    学生
# 142    59>岁    职员
# 143    59>岁    其他
# 144  30-44岁    职员
# 145  30-44岁    其他
# 146    59>岁    无业
# 147    59>岁    无业
# 148    <15岁    无业
# ...

# %%
dates = pd.date_range('20180911', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2018-09-11', '2018-09-12', '2018-09-13', '2018-09-14',
#                '2018-09-15', '2018-09-16'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2018-09-11  1.146050  3.406174 -1.053599 -0.260395
# 2018-09-12  0.364072  0.699473  1.277655 -0.380723
# 2018-09-13  0.521003 -0.841020  0.989779  0.556936
# 2018-09-14  0.781989  0.580371 -0.825308  1.919033
# 2018-09-15 -0.459775  0.461197 -1.232318 -1.622561
# 2018-09-16  0.507916 -0.735724 -0.136494 -0.492330

# %%
df2 = pd.DataFrame({
    'A': 1.,
    'B': pd.Timestamp('20180912'),
    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
    'D': np.array([3] * 4, dtype='int32'),
    'E': pd.Categorical(["test", "train", "test", "train"]),
    'F': 'foo'
})

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2018-09-12  1.0  3   test  foo
# 1  1.0 2018-09-12  1.0  3  train  foo
# 2  1.0 2018-09-12  1.0  3   test  foo
# 3  1.0 2018-09-12  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
records.iloc[1, -1]
# Out:
# '群众组织'

# %%
records.iloc[1, 1]
# Out:
# '其他'

# %%
records[records > 15]
# Out:
#        年龄区间    职业  参与年限      单次时长   每周频次         了解途径     参与途径
# 0    15-29岁    学生  小于1年  45--60分钟   每周1次   亲身参与培训, 比赛   参与各级比赛
# 1    30-44岁    其他  小于1年   大于120分钟   每天多次   亲身参与培训, 比赛     群众组织
# 2    30-44岁  自由职业  大于5年  60--90分钟  每周4-5  媒体(互联网, 手机)     视频学习
# 3    15-29岁    职员  3-5年   大于120分钟   每天多次  媒体(互联网, 手机)   参与各级比赛
# 4    30-44岁    其他  大于5年  60--90分钟     其他   亲身参与培训, 比赛  参与专门的培训
# 5    30-44岁    职员  小于1年    小于45分钟  每周4-5   亲身参与培训, 比赛   参与各级比赛
# 6    45-59岁  自由职业  小于1年    小于45分钟   每周1次         朋友介绍     群众组织
# 7      <15岁    其他  大于5年    小于45分钟  每周4-5  媒体(互联网, 手机)     视频学习
# 8      <15岁    学生  3-5年     120分钟   每周1次        书刊,杂志     视频学习
# 9    30-44岁    职员  小于1年     120分钟  每周4-5  媒体(互联网, 手机)     视频学习
# 10     <15岁    职员  小于1年  45--60分钟   每周1次   亲身参与培训, 比赛     群众组织
# 11     <15岁    职员  3-5年   大于120分钟  每周4-5         朋友介绍  参与专门的培训
# 12     <15岁    职员  3-5年    小于45分钟  每周4-5  媒体(互联网, 手机)  参与专门的培训
# 13   15-29岁  自由职业  大于5年   大于120分钟   每天1次   亲身参与培训, 比赛     视频学习
# ...

# %%
df2 = records.copy()

# %%
df2['综合'] = ['好', '良', '差', '优'] * 40

# %%
df2
# Out:
#        年龄区间    职业  参与年限      单次时长   每周频次         了解途径     参与途径 综合
# 0    15-29岁    学生  小于1年  45--60分钟   每周1次   亲身参与培训, 比赛   参与各级比赛  好
# 1    30-44岁    其他  小于1年   大于120分钟   每天多次   亲身参与培训, 比赛     群众组织  良
# 2    30-44岁  自由职业  大于5年  60--90分钟  每周4-5  媒体(互联网, 手机)     视频学习  差
# 3    15-29岁    职员  3-5年   大于120分钟   每天多次  媒体(互联网, 手机)   参与各级比赛  优
# 4    30-44岁    其他  大于5年  60--90分钟     其他   亲身参与培训, 比赛  参与专门的培训  好
# 5    30-44岁    职员  小于1年    小于45分钟  每周4-5   亲身参与培训, 比赛   参与各级比赛  良
# 6    45-59岁  自由职业  小于1年    小于45分钟   每周1次         朋友介绍     群众组织  差
# 7      <15岁    其他  大于5年    小于45分钟  每周4-5  媒体(互联网, 手机)     视频学习  优
# 8      <15岁    学生  3-5年     120分钟   每周1次        书刊,杂志     视频学习  好
# 9    30-44岁    职员  小于1年     120分钟  每周4-5  媒体(互联网, 手机)     视频学习  良
# 10     <15岁    职员  小于1年  45--60分钟   每周1次   亲身参与培训, 比赛     群众组织  差
# 11     <15岁    职员  3-5年   大于120分钟  每周4-5         朋友介绍  参与专门的培训  优
# 12     <15岁    职员  3-5年    小于45分钟  每周4-5  媒体(互联网, 手机)  参与专门的培训  好
# ...

# %%
df2[df2['综合'].isin(['优', '好'])] # 这里原本想要获取综合为 优 或者 好
# Out:
#        年龄区间    职业  参与年限      单次时长   每周频次         了解途径     参与途径 综合
# 0    15-29岁    学生  小于1年  45--60分钟   每周1次   亲身参与培训, 比赛   参与各级比赛  好
# 3    15-29岁    职员  3-5年   大于120分钟   每天多次  媒体(互联网, 手机)   参与各级比赛  优
# 4    30-44岁    其他  大于5年  60--90分钟     其他   亲身参与培训, 比赛  参与专门的培训  好
# 7      <15岁    其他  大于5年    小于45分钟  每周4-5  媒体(互联网, 手机)     视频学习  优
# 8      <15岁    学生  3-5年     120分钟   每周1次        书刊,杂志     视频学习  好
# 11     <15岁    职员  3-5年   大于120分钟  每周4-5         朋友介绍  参与专门的培训  优
# 12     <15岁    职员  3-5年    小于45分钟  每周4-5  媒体(互联网, 手机)  参与专门的培训  好
# 15   45-59岁    学生  1-3年  45--60分钟  每周4-5         朋友介绍     群众组织  优
# 16     59>岁    无业  大于5年    小于45分钟  每周4-5         朋友介绍     群众组织  好
# 19   30-44岁    无业  小于1年   大于120分钟     其他  媒体(互联网, 手机)     视频学习  优
# 20     <15岁    学生  1-3年  45--60分钟  每周4-5   亲身参与培训, 比赛   参与各级比赛  好
# 23     59>岁    学生  小于1年  45--60分钟     其他   亲身参与培训, 比赛  参与专门的培训  优
# 24   15-29岁    学生  3-5年    小于45分钟  每周4-5   亲身参与培训, 比赛     视频学习  好
# ...

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20180911', periods=6))

# %%
s1
# Out:
# 2018-09-11    1
# 2018-09-12    2
# 2018-09-13    3
# 2018-09-14    4
# 2018-09-15    5
# 2018-09-16    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %%
df
# Out:
#                    A         B         C         D  F
# 2018-09-11  1.146050  3.406174 -1.053599 -0.260395  1
# 2018-09-12  0.364072  0.699473  1.277655 -0.380723  2
# 2018-09-13  0.521003 -0.841020  0.989779  0.556936  3
# 2018-09-14  0.781989  0.580371 -0.825308  1.919033  4
# 2018-09-15 -0.459775  0.461197 -1.232318 -1.622561  5
# 2018-09-16  0.507916 -0.735724 -0.136494 -0.492330  6

# %% [markdown]
# ###  settings values by lable

# %%
df.at[dates[0], 'A'] = 0

# %%
df
# Out:
#                    A         B         C         D  F
# 2018-09-11  0.000000  3.406174 -1.053599 -0.260395  1
# 2018-09-12  0.364072  0.699473  1.277655 -0.380723  2
# 2018-09-13  0.521003 -0.841020  0.989779  0.556936  3
# 2018-09-14  0.781989  0.580371 -0.825308  1.919033  4
# 2018-09-15 -0.459775  0.461197 -1.232318 -1.622561  5
# 2018-09-16  0.507916 -0.735724 -0.136494 -0.492330  6

# %% [markdown]
# ### settting values by position

# %%
df.iat[0,1] = 1

# %%
df
# Out:
#                    A         B         C         D  F
# 2018-09-11  0.000000  1.000000 -1.053599 -0.260395  1
# 2018-09-12  0.364072  0.699473  1.277655 -0.380723  2
# 2018-09-13  0.521003 -0.841020  0.989779  0.556936  3
# 2018-09-14  0.781989  0.580371 -0.825308  1.919033  4
# 2018-09-15 -0.459775  0.461197 -1.232318 -1.622561  5
# 2018-09-16  0.507916 -0.735724 -0.136494 -0.492330  6

# %% [markdown]
# ### Settings by assigning with a NumPy array

# %%
df.loc[:, 'D'] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C  D  F
# 2018-09-11  0.000000  1.000000 -1.053599  5  1
# 2018-09-12  0.364072  0.699473  1.277655  5  2
# 2018-09-13  0.521003 -0.841020  0.989779  5  3
# 2018-09-14  0.781989  0.580371 -0.825308  5  4
# 2018-09-15 -0.459775  0.461197 -1.232318  5  5
# 2018-09-16  0.507916 -0.735724 -0.136494  5  6

# %% [markdown]
# ###  a where operations with setttings

# %%
df2 = df.copy()

# %%
df2[df2>0] = -df2

# %%
df2
# Out:
#                    A         B         C  D  F
# 2018-09-11  0.000000 -1.000000 -1.053599 -5 -1
# 2018-09-12 -0.364072 -0.699473 -1.277655 -5 -2
# 2018-09-13 -0.521003 -0.841020 -0.989779 -5 -3
# 2018-09-14 -0.781989 -0.580371 -0.825308 -5 -4
# 2018-09-15 -0.459775 -0.461197 -1.232318 -5 -5
# 2018-09-16 -0.507916 -0.735724 -0.136494 -5 -6

# %% [markdown]
# # Missing Data

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])

# %%
df1.loc[dates[0]: dates[1], 'E'] = 1

# %%
df1
# Out:
#                    A         B         C  D  F    E
# 2018-09-11  0.000000  1.000000 -1.053599  5  1  1.0
# 2018-09-12  0.364072  0.699473  1.277655  5  2  1.0
# 2018-09-13  0.521003 -0.841020  0.989779  5  3  NaN
# 2018-09-14  0.781989  0.580371 -0.825308  5  4  NaN

# %% [markdown]
# ### To drop any rows that have missing data

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C  D  F    E
# 2018-09-11  0.000000  1.000000 -1.053599  5  1  1.0
# 2018-09-12  0.364072  0.699473  1.277655  5  2  1.0

# %% [markdown]
# ### Filling missing data.

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D  F    E
# 2018-09-11  0.000000  1.000000 -1.053599  5  1  1.0
# 2018-09-12  0.364072  0.699473  1.277655  5  2  1.0
# 2018-09-13  0.521003 -0.841020  0.989779  5  3  5.0
# 2018-09-14  0.781989  0.580371 -0.825308  5  4  5.0

# %% [markdown]
# ### To get the boolean mask where values are nan.

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2018-09-11  False  False  False  False  False  False
# 2018-09-12  False  False  False  False  False  False
# 2018-09-13  False  False  False  False  False   True
# 2018-09-14  False  False  False  False  False   True

# %% [markdown]
# # Operations

# %% [markdown]
#  ### Performing a descriptive statistic

# %%
df.mean()
# Out:
# A    0.285868
# B    0.194049
# C   -0.163381
# D    5.000000
# F    3.500000
# dtype: float64

# %% [markdown]
# ### Same operation on the other axis

# %%
df.mean(1)
# Out:
# 2018-09-11    1.189280
# 2018-09-12    1.868240
# 2018-09-13    1.733952
# 2018-09-14    1.907410
# 2018-09-15    1.753821
# 2018-09-16    2.127139
# Freq: D, dtype: float64

# %% [markdown]
# ### Operating with objects that have different dimensionality and need alignment. In addition, pandas automatically broadcasts along the specified dimension

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

# %%
s
# Out:
# 2018-09-11    NaN
# 2018-09-12    NaN
# 2018-09-13    1.0
# 2018-09-14    3.0
# 2018-09-15    5.0
# 2018-09-16    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2018-09-11       NaN       NaN       NaN  NaN  NaN
# 2018-09-12       NaN       NaN       NaN  NaN  NaN
# 2018-09-13 -0.478997 -1.841020 -0.010221  4.0  2.0
# 2018-09-14 -2.218011 -2.419629 -3.825308  2.0  1.0
# 2018-09-15 -5.459775 -4.538803 -6.232318  0.0  0.0
# 2018-09-16       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# # Apply

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D   F
# 2018-09-11  0.000000  1.000000 -1.053599   5   1
# 2018-09-12  0.364072  1.699473  0.224056  10   3
# 2018-09-13  0.885075  0.858453  1.213835  15   6
# 2018-09-14  1.667065  1.438824  0.388526  20  10
# 2018-09-15  1.207290  1.900020 -0.843792  25  15
# 2018-09-16  1.715205  1.164296 -0.980286  30  21

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    1.241765
# B    1.841020
# C    2.509972
# D    0.000000
# F    5.000000
# dtype: float64

# %% [markdown]
# # Histogramming

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    6
# 1    0
# 2    5
# 3    6
# 4    3
# 5    3
# 6    4
# 7    1
# 8    6
# 9    6
# dtype: int64

# %%
s.value_counts()
# Out:
# 6    4
# 3    2
# 5    1
# 4    1
# 1    1
# 0    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10,4))

# %%
df
# Out:
#           0         1         2         3
# 0 -0.376216 -1.069294  0.849687  0.140240
# 1  0.359708  1.161887 -0.123527  1.123719
# 2 -0.246537 -1.217673  1.727424 -1.469981
# 3  0.056617 -1.873066 -0.792786  0.662441
# 4  0.357817  0.575396 -0.165876  0.011559
# 5  1.017582 -0.275206 -0.624788  0.242692
# 6 -0.216522 -0.071179 -0.284284 -0.900113
# 7  0.718698  0.087928  0.679666 -0.529452
# 8  0.597636 -0.006687  0.208747  0.568173
# 9 -0.050485 -0.691251 -0.475646  1.435867

# %%
pieces = [df[:3], df[3:7], df[7:]]

# %%
pieces
# Out:
# [          0         1         2         3
#  0 -0.376216 -1.069294  0.849687  0.140240
#  1  0.359708  1.161887 -0.123527  1.123719
#  2 -0.246537 -1.217673  1.727424 -1.469981,
#            0         1         2         3
#  3  0.056617 -1.873066 -0.792786  0.662441
#  4  0.357817  0.575396 -0.165876  0.011559
#  5  1.017582 -0.275206 -0.624788  0.242692
#  6 -0.216522 -0.071179 -0.284284 -0.900113,
#            0         1         2         3
#  7  0.718698  0.087928  0.679666 -0.529452
#  8  0.597636 -0.006687  0.208747  0.568173
#  9 -0.050485 -0.691251 -0.475646  1.435867]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.376216 -1.069294  0.849687  0.140240
# 1  0.359708  1.161887 -0.123527  1.123719
# 2 -0.246537 -1.217673  1.727424 -1.469981
# 3  0.056617 -1.873066 -0.792786  0.662441
# 4  0.357817  0.575396 -0.165876  0.011559
# 5  1.017582 -0.275206 -0.624788  0.242692
# 6 -0.216522 -0.071179 -0.284284 -0.900113
# 7  0.718698  0.087928  0.679666 -0.529452
# 8  0.597636 -0.006687  0.208747  0.568173
# 9 -0.050485 -0.691251 -0.475646  1.435867

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})

# %%
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left=left, right=right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# # Append

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D'])

# %%
df
# Out:
#           A         B         C         D
# 0  0.456613 -2.078794 -0.137144 -0.199210
# 1 -1.086086 -0.855046  0.902825  0.641487
# 2  0.872235  0.438142  0.188537 -0.114681
# 3 -0.893063 -0.607349  0.368385  1.063320
# 4  0.033166 -1.590900 -0.743594 -0.514025
# 5  0.201276  1.446113 -0.825070 -0.747308
# 6  0.127554 -1.337883 -0.812601  0.898726
# 7  1.092710  1.027291  0.980834  0.799222

# %%
s = df.iloc[3]

# %%
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0  0.456613 -2.078794 -0.137144 -0.199210
# 1 -1.086086 -0.855046  0.902825  0.641487
# 2  0.872235  0.438142  0.188537 -0.114681
# 3 -0.893063 -0.607349  0.368385  1.063320
# 4  0.033166 -1.590900 -0.743594 -0.514025
# 5  0.201276  1.446113 -0.825070 -0.747308
# 6  0.127554 -1.337883 -0.812601  0.898726
# 7  1.092710  1.027291  0.980834  0.799222
# 8 -0.893063 -0.607349  0.368385  1.063320

# %% [markdown]
# # Grouping
# ####  By "group by" we are referring to a process involving one or more of the following steps:
# > - **Splitting** the data into groups based on some criteria
# > - **Applying** a function to each group independently
# > - **Combining** the results into a data structure

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
   ....:                           'foo', 'bar', 'foo', 'foo'],
   ....:                    'B' : ['one', 'one', 'two', 'three',
   ....:                           'two', 'two', 'one', 'three'],
   ....:                    'C' : np.random.randn(8),
   ....:                    'D' : np.random.randn(8)})
   ....:

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  0.314166 -1.884147
# 1  bar    one  0.548100 -0.153274
# 2  foo    two -0.975688  0.070151
# 3  bar  three  1.712571 -2.082122
# 4  foo    two  1.032722  1.173095
# 5  bar    two  0.263866  0.791779
# 6  foo    one  0.123939  0.669047
# 7  foo  three  0.295996  0.283002

# %% [markdown]
# ### Grouping and then applying the sum() function to the resulting groups.

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  2.524536 -1.443618
# foo  0.791134  0.311147

# %% [markdown]
# ### Grouping and then applying the sum() function to the resulting groups.

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.548100 -0.153274
#     three  1.712571 -2.082122
#     two    0.263866  0.791779
# foo one    0.438105 -1.215100
#     three  0.295996  0.283002
#     two    0.057034  1.243246

# %% [markdown]
# # Reshaping

# %% [markdown]
# ## stack

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
   ....:                      'foo', 'foo', 'qux', 'qux'],
   ....:                     ['one', 'two', 'one', 'two',
   ....:                      'one', 'two', 'one', 'two']]))

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])

# %%
index
# Out:
# MultiIndex(levels=[['bar', 'baz', 'foo', 'qux'], ['one', 'two']],
#            labels=[[0, 0, 1, 1, 2, 2, 3, 3], [0, 1, 0, 1, 0, 1, 0, 1]],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])

# %%
df
# Out:
#                      A         B
# first second
# bar   one     0.080907  1.877977
#       two    -0.743779 -0.183575
# baz   one     0.389073  0.497882
#       two    -0.887165 -0.745038
# foo   one    -0.146645  0.155743
#       two     0.484190  0.931752
# qux   one     0.036482  0.544175
#       two     0.999977  0.554058

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one     0.080907  1.877977
#       two    -0.743779 -0.183575
# baz   one     0.389073  0.497882
#       two    -0.887165 -0.745038

# %% [markdown]
# ### The stack() method “compresses” a level in the DataFrame’s columns.

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A    0.080907
#                B    1.877977
#        two     A   -0.743779
#                B   -0.183575
# baz    one     A    0.389073
#                B    0.497882
#        two     A   -0.887165
#                B   -0.745038
# dtype: float64

# %% [markdown]
# ### With a “stacked” DataFrame or Series (having a MultiIndex as the index), the inverse operation of stack() is unstack(), which by default unstacks the last level:

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.080907  1.877977
#       two    -0.743779 -0.183575
# baz   one     0.389073  0.497882
#       two    -0.887165 -0.745038

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.080907 -0.743779
#       B  1.877977 -0.183575
# baz   A  0.389073 -0.887165
#       B  0.497882 -0.745038

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  0.080907  0.389073
#        B  1.877977  0.497882
# two    A -0.743779 -0.887165
#        B -0.183575 -0.745038

# %% [markdown]
# ## Pivot Tables

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
   .....:                    'B' : ['A', 'B', 'C'] * 4,
   .....:                    'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
   .....:                    'D' : np.random.randn(12),
   .....:                    'E' : np.random.randn(12)})

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.308175 -2.255716
# 1     one  B  foo  0.978715  0.488768
# 2     two  C  foo  3.212971  0.478341
# 3   three  A  bar -1.732779 -0.103511
# 4     one  B  bar -0.979968 -0.379028
# 5     one  C  bar -0.594313  2.309035
# 6     two  A  foo  0.072588 -0.510867
# 7   three  B  foo -0.275574 -0.615750
# 8     one  C  foo -0.250258 -0.730939
# 9     one  A  bar -0.382496 -1.261512
# 10    two  B  bar  0.984268  0.712836
# 11  three  C  bar -0.803136  0.999335

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -0.382496  0.308175
#       B -0.979968  0.978715
#       C -0.594313 -0.250258
# three A -1.732779       NaN
#       B       NaN -0.275574
#       C -0.803136       NaN
# two   A       NaN  0.072588
#       B  0.984268       NaN
#       C       NaN  3.212971

# %% [markdown]
# ## Time Series

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')

# %%
rng
# Out:
# DatetimeIndex(['2012-01-01 00:00:00', '2012-01-01 00:00:01',
#                '2012-01-01 00:00:02', '2012-01-01 00:00:03',
#                '2012-01-01 00:00:04', '2012-01-01 00:00:05',
#                '2012-01-01 00:00:06', '2012-01-01 00:00:07',
#                '2012-01-01 00:00:08', '2012-01-01 00:00:09',
#                '2012-01-01 00:00:10', '2012-01-01 00:00:11',
#                '2012-01-01 00:00:12', '2012-01-01 00:00:13',
#                '2012-01-01 00:00:14', '2012-01-01 00:00:15',
#                '2012-01-01 00:00:16', '2012-01-01 00:00:17',
#                '2012-01-01 00:00:18', '2012-01-01 00:00:19',
#                '2012-01-01 00:00:20', '2012-01-01 00:00:21',
#                '2012-01-01 00:00:22', '2012-01-01 00:00:23',
#                '2012-01-01 00:00:24', '2012-01-01 00:00:25',
#                '2012-01-01 00:00:26', '2012-01-01 00:00:27',
#                '2012-01-01 00:00:28', '2012-01-01 00:00:29',
# ...

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts
# Out:
# 2012-01-01 00:00:00    484
# 2012-01-01 00:00:01    112
# 2012-01-01 00:00:02    186
# 2012-01-01 00:00:03    373
# 2012-01-01 00:00:04    387
# 2012-01-01 00:00:05    391
# 2012-01-01 00:00:06    143
# 2012-01-01 00:00:07    357
# 2012-01-01 00:00:08    283
# 2012-01-01 00:00:09    423
# 2012-01-01 00:00:10    248
# 2012-01-01 00:00:11    104
# 2012-01-01 00:00:12    255
# 2012-01-01 00:00:13    347
# 2012-01-01 00:00:14    452
# 2012-01-01 00:00:15    261
# 2012-01-01 00:00:16    413
# 2012-01-01 00:00:17    439
# 2012-01-01 00:00:18    150
# 2012-01-01 00:00:19    276
# 2012-01-01 00:00:20    334
# 2012-01-01 00:00:21    437
# 2012-01-01 00:00:22    364
# 2012-01-01 00:00:23    198
# 2012-01-01 00:00:24    460
# 2012-01-01 00:00:25    342
# 2012-01-01 00:00:26    129
# 2012-01-01 00:00:27    241
# 2012-01-01 00:00:28    101
# 2012-01-01 00:00:29    168
#                       ...
# 2012-01-01 00:01:10    438
# 2012-01-01 00:01:11    210
# 2012-01-01 00:01:12    232
# ...

# %%
ts.resample('5Min').sum()
# Out:
# 2012-01-01    27231
# Freq: 5T, dtype: int64

# %% [markdown]
# ### Time zone representation:

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06    0.181946
# 2012-03-07   -0.151821
# 2012-03-08    0.209034
# 2012-03-09    0.139019
# 2012-03-10    0.438666
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    0.181946
# 2012-03-07 00:00:00+00:00   -0.151821
# 2012-03-08 00:00:00+00:00    0.209034
# 2012-03-09 00:00:00+00:00    0.139019
# 2012-03-10 00:00:00+00:00    0.438666
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00    0.181946
# 2012-03-06 19:00:00-05:00   -0.151821
# 2012-03-07 19:00:00-05:00    0.209034
# 2012-03-08 19:00:00-05:00    0.139019
# 2012-03-09 19:00:00-05:00    0.438666
# Freq: D, dtype: float64

# %% [markdown]
# ### Converting between time span representations:

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')

# %%
rng
# Out:
# DatetimeIndex(['2012-01-31', '2012-02-29', '2012-03-31', '2012-04-30',
#                '2012-05-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts
# Out:
# 2012-01-31   -1.110082
# 2012-02-29    0.504074
# 2012-03-31    0.740995
# 2012-04-30    1.801643
# 2012-05-31    0.153776
# Freq: M, dtype: float64

# %%
ps = ts.to_period()

# %%
ps
# Out:
# 2012-01   -1.110082
# 2012-02    0.504074
# 2012-03    0.740995
# 2012-04    1.801643
# 2012-05    0.153776
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01   -1.110082
# 2012-02-01    0.504074
# 2012-03-01    0.740995
# 2012-04-01    1.801643
# 2012-05-01    0.153776
# Freq: MS, dtype: float64

# %% [markdown]
# #### Converting between period and timestamp enables some convenient arithmetic functions to be used. In the following example, we convert a quarterly frequency with year ending in November to 9am of the end of the month following the quarter end:

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')

# %%
prng
# Out:
# PeriodIndex(['1990Q1', '1990Q2', '1990Q3', '1990Q4', '1991Q1', '1991Q2',
#              '1991Q3', '1991Q4', '1992Q1', '1992Q2', '1992Q3', '1992Q4',
#              '1993Q1', '1993Q2', '1993Q3', '1993Q4', '1994Q1', '1994Q2',
#              '1994Q3', '1994Q4', '1995Q1', '1995Q2', '1995Q3', '1995Q4',
#              '1996Q1', '1996Q2', '1996Q3', '1996Q4', '1997Q1', '1997Q2',
#              '1997Q3', '1997Q4', '1998Q1', '1998Q2', '1998Q3', '1998Q4',
#              '1999Q1', '1999Q2', '1999Q3', '1999Q4', '2000Q1', '2000Q2',
#              '2000Q3', '2000Q4'],
#             dtype='period[Q-NOV]', freq='Q-NOV')

# %%
ts = pd.Series(np.random.randn(len(prng)), prng)

# %%
ts
# Out:
# 1990Q1   -0.660702
# 1990Q2   -0.873173
# 1990Q3   -0.359912
# 1990Q4   -1.209806
# 1991Q1    0.838127
# 1991Q2   -0.897298
# 1991Q3    1.546495
# 1991Q4    0.180118
# 1992Q1   -1.470551
# 1992Q2    1.063113
# 1992Q3    0.817819
# 1992Q4    0.075106
# 1993Q1   -0.412603
# 1993Q2    0.005357
# 1993Q3   -0.682316
# 1993Q4    1.410667
# 1994Q1   -0.715989
# 1994Q2   -0.689675
# 1994Q3   -0.510815
# 1994Q4    0.699771
# 1995Q1    0.044356
# 1995Q2   -0.349935
# 1995Q3    0.617584
# 1995Q4    0.027081
# 1996Q1    0.914066
# 1996Q2    0.068461
# 1996Q3    0.622456
# 1996Q4    0.641236
# 1997Q1   -1.640274
# 1997Q2   -1.229792
# 1997Q3   -0.490135
# 1997Q4   -0.342151
# 1998Q1   -0.890498
# 1998Q2    0.524390
# 1998Q3   -0.735124
# 1998Q4    0.445963
# 1999Q1    0.607710
# 1999Q2    1.136165
# 1999Q3   -0.365908
# 1999Q4    0.335214
# 2000Q1   -0.076688
# 2000Q2   -1.855518
# 2000Q3   -0.711213
# 2000Q4   -0.199246
# Freq: Q-NOV, dtype: float64

# %%
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9

# %%
ts
# Out:
# 1990-03-01 09:00   -0.660702
# 1990-06-01 09:00   -0.873173
# 1990-09-01 09:00   -0.359912
# 1990-12-01 09:00   -1.209806
# 1991-03-01 09:00    0.838127
# 1991-06-01 09:00   -0.897298
# 1991-09-01 09:00    1.546495
# 1991-12-01 09:00    0.180118
# 1992-03-01 09:00   -1.470551
# 1992-06-01 09:00    1.063113
# 1992-09-01 09:00    0.817819
# 1992-12-01 09:00    0.075106
# 1993-03-01 09:00   -0.412603
# 1993-06-01 09:00    0.005357
# 1993-09-01 09:00   -0.682316
# 1993-12-01 09:00    1.410667
# 1994-03-01 09:00   -0.715989
# 1994-06-01 09:00   -0.689675
# 1994-09-01 09:00   -0.510815
# 1994-12-01 09:00    0.699771
# 1995-03-01 09:00    0.044356
# 1995-06-01 09:00   -0.349935
# 1995-09-01 09:00    0.617584
# 1995-12-01 09:00    0.027081
# 1996-03-01 09:00    0.914066
# 1996-06-01 09:00    0.068461
# 1996-09-01 09:00    0.622456
# 1996-12-01 09:00    0.641236
# 1997-03-01 09:00   -1.640274
# 1997-06-01 09:00   -1.229792
# 1997-09-01 09:00   -0.490135
# 1997-12-01 09:00   -0.342151
# ...

# %%
ts.head()
# Out:
# 1990-03-01 09:00   -0.660702
# 1990-06-01 09:00   -0.873173
# 1990-09-01 09:00   -0.359912
# 1990-12-01 09:00   -1.209806
# 1991-03-01 09:00    0.838127
# Freq: H, dtype: float64

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})

# %%
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
 df["grade"].cat.categories = ["very good", "good", "very bad"]

# %%
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])

# %%
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %% [markdown]
# ## Plotting

# %%
 ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
   .....:                   columns=['A', 'B', 'C', 'D'])

# %%
df = df.cumsum()

# %%
plt.figure(); df.plot(); plt.legend(loc='best')
